# %% [markdown]
# <a href="https://colab.research.google.com/github/duc-ke/kaggle-playground-group/blob/main/7.CT_lung_segmentation/st2_1_inference(keras_simpleUnet)_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inference (Keras ver.)
# * dataload
# * model load
# * inference

# %%
# !git clone https://github.com/duc-ke/kaggle-playground-group.git
# Out:
# Cloning into 'kaggle-playground-group'...
# remote: Enumerating objects: 439, done.
# remote: Counting objects: 100% (439/439), done.
# remote: Compressing objects: 100% (346/346), done.
# remote: Total 439 (delta 209), reused 270 (delta 88), pack-reused 0
# Receiving objects: 100% (439/439), 180.38 MiB | 19.34 MiB/s, done.
# Resolving deltas: 100% (209/209), done.
# Checking out files: 100% (78/78), done.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# # Data loading

# %%
x_val = np.load('kaggle-playground-group/7.CT_lung_segmentation/dataset/x_val.npy')
y_val = np.load('kaggle-playground-group/7.CT_lung_segmentation/dataset/y_val.npy')
print(x_val.shape, y_val.shape)
# Out:
# (27, 256, 256, 1) (27, 256, 256, 1)

# %% [markdown]
# # model loading

# %%
dir_path = 'kaggle-playground-group/7.CT_lung_segmentation/models'
model_f = os.path.join(dir_path, 'lung_ct_keras.h5')
model = tf.keras.models.load_model(model_f)

# %% [markdown]
# # Inference

# %%
preds = model.predict(x_val)

fig, ax = plt.subplots(len(x_val), 3, figsize=(10, 100))

for i, pred in enumerate(preds):
    ax[i, 0].imshow(x_val[i].squeeze(), cmap='gray')
    ax[i, 1].imshow(y_val[i].squeeze(), cmap='gray')
    ax[i, 2].imshow(pred.squeeze(), cmap='gray')
